# %%
import pandas as pd
df = pd.read_csv("2019.csv")

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
cols=[0,3,4,5,6,7,8]
df.drop(df.columns[cols], axis=1,inplace=True)

# %%
df
# Out:
#             Country or region  Score
# 0                     Finland  7.769
# 1                     Denmark  7.600
# 2                      Norway  7.554
# 3                     Iceland  7.494
# 4                 Netherlands  7.488
# ..                        ...    ...
# 151                    Rwanda  3.334
# 152                  Tanzania  3.231
# 153               Afghanistan  3.203
# 154  Central African Republic  3.083
# 155               South Sudan  2.853
#
# [156 rows x 2 columns]

# %%
df.head()
# Out:
#   Country or region  Score
# 0           Finland  7.769
# 1           Denmark  7.600
# 2            Norway  7.554
# 3           Iceland  7.494
# 4       Netherlands  7.488

# %%
df.columns
# Out:
# Index(['Country or region', 'Score'], dtype='object')

# %%
OldToNew={df.columns[0]:'countryorregion',df.columns[1]:'scoreofhappiness'}
df.rename(columns=OldToNew,inplace=True)
df.head()
# Out:
#   countryorregion  scoreofhappiness
# 0         Finland             7.769
# 1         Denmark             7.600
# 2          Norway             7.554
# 3         Iceland             7.494
# 4     Netherlands             7.488

# %%
df.tail()
# Out:
#               countryorregion  scoreofhappiness
# 151                    Rwanda             3.334
# 152                  Tanzania             3.231
# 153               Afghanistan             3.203
# 154  Central African Republic             3.083
# 155               South Sudan             2.853

# %%
df.dtypes
# Out:
# countryorregion      object
# scoreofhappiness    float64
# dtype: object

# %%
df.to_pickle("2019happiness.pkl")

# %%
from rpy2.robjects import pandas2ri 
pandas2ri.activate() 

from rpy2.robjects.packages import importr

base = importr('base') 
base.saveRDS(df,file="2019happiness.RDS")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/rpy2/robjects/vectors.py:927: UserWarning: R object inheriting from "POSIXct" but without attribute "tzone".
#   warnings.warn('R object inheriting from "POSIXct" but without '
# <rpy2.rinterface.NULLType object at 0x1201c81e0> [RTYPES.NILSXP]
